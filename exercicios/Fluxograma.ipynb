# %% [markdown]
# <a href="https://colab.research.google.com/github/LorenzoMuller/logicadeprogramacao/blob/main/exercicios/Fluxograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Calcular Média
# ![image.png](data:image/png;base64,...)

# %%
#entrada

P1 = float(input("digite a nota da primeira avaliação: "))
P2 = float(input("digite a nota da segunda avaliação: "))

#processamento
A = (P1+P2)/2

#saida
print("a média do aluno é:", A)
# Out:
# digite a nota da primeira avaliação: 8
# digite a nota da segunda avaliação: 4
# a média do aluno é: 6.0

# %% [markdown]
# # Cotação do Dólar
# ![image.png](data:image/png;base64,...)

# %%
# entrada
CD = float(input("Digite a cotação do dolár atual: "))
RD = float(input("Digite o valor a ser convertido em real para dólar: "))

#processamento
conversao = RD/CD
#saida
print("a cotação do dólar é: R$", conversao)
# Out:
# Digite a cotação do dolár atual: 5.02
# Digite o valor a ser convertido em real para dólar: 50.18
# a cotação do dólar é: $ 9.996015936254981

# %% [markdown]
# # Quadrado e Soma
# ![image.png](data:image/png;base64,...)

# %%
# entrada
N1 = float(input(" digite o primeiro numero:"))
N2 = float(input(" digite o segundo numero:"))
N3 = float(input(" digite o terceiro numero:"))
N4 = float(input(" digite o quarto numero:"))
#processamento
N1Q = N1**2
N2Q = N2**2
N3Q = N3**2
N4Q = N4**2
Resultado = N1Q+N2Q+N3Q+N4Q
#saida
print ("a soma doa quadrados dos números é:", Resultado)
# Out:
#  digite o primeiro numero:2
#  digite o segundo numero:4
#  digite o terceiro numero:5
#  digite o quarto numero:6
# a soma doa quadrados dos números é: 81.0

# %% [markdown]
# #Comissão
# ![image.png](data:image/png;base64,...)

# %%
#entrada
vup = float(input("insira o valor unitário do produto: R$"))
qv = float(input("insira a qauntidade de produtos vendidos: "))
#processamento
Vvendas = vup*qv
comissao = Vvendas*0.05
#saida
print("O valor total em vendas é: R$", Vvendas)
print("A comissão do vendedor é: R$", comissao)
# Out:
# insira o valor unitário do produto: R$2.50
# insira a qauntidade de produtos vendidos: 200
# O valor total em vendas é: R$ 500.0
# A comissão do vendedor é: R$ 25.0

# %% [markdown]
# # Custo do Carro
# ![image.png](data:image/png;base64,...)

# %%
#entrada
cc = float(input("Insira o valor da fábrica do carro: R$ "))
#processamento
ci = cc*0.45
ci2 = cc+ci
cti = ci2*0.28
vc = cc+ci+cti
#saida
print("O valor do carro paar o consumidor é: R$", vc)
# Out:
# Insira o valor da fábrica do carro: R$ 25000
# O valor do carro paar o consumidor é: R$ 46400.0

# %% [markdown]
# # Horas Extras
# ![image.png](data:image/png;base64,...)

# %%
# entrada
ht = float(input("insira as horas trabalhadas: "))
m = float(input("insira os minutos trabalhadas: "))
vh = float(input("insira o valor recebido por hora ; R$ "))
#processamento
ms = m/60
tt = ht+ms
sd = vh*tt
res1 = sd*0.7
res2 = res1+sd
#saida
print("O funcionário vai receber: R$", res2)
# Out:
# insira as horas trabalhadas: 15
# insira os minutos trabalhadas: 45
# insira o valor recebido por hora ; R$ 100
# O funcionário vai receber: R$ 2677.5

# %% [markdown]
# # Gasolina
# ![image.png](data:image/png;base64,...)

# %%
#entrada
d = float(input("Insira a distancia em  KM  a ser percorrida:"))
c = float(input("insira quantos KM o seu carro ainda por litro:"))
pg = float(input("insira o preço da gasolina:"))
#processamento
lgn = d/c
gastoG = pg*lgn
res = gastoG*2
#saida
print("voce gastara para ir R$:", gastoG , "ou R$",res,"para ir e voltar")

# %% [markdown]
# # Velocidade média de um carro
# ![image.png](data:image/png;base64,...)

# %%
#entrada
d = float(input("insira a distancia em KM do percurso percorrido:"))
hg = float(input("insira as horas gastas para terminar o percurso:"))
mg = float(input("Agora insira os minutos gastos para terminar o percurso:"))
#processamento
ms =  mg/60
tt = hg+ms
vm = d/tt
#saida
print("A velocidade meia do carro é:", vm)
